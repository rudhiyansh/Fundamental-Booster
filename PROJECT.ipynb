# %%
welcome="Welcome to the interactive personal data collector!"

print(welcome, "\n")

Name=str(input("please enter your name: "))
Age=int(input("please enter your age: "))
Height=float(input("plaese enter your height in meters: "))
Fav_num=int(input("please enter your favourite number: "))

greet="\nThank you!, Here is the imformation we collected:"
print(greet, "\n")

print(f"Name:", Name, ("Type:", type(Name),"Memory Address:", id(Name)))
print(f"Age:", Age, ("Type:", type(Age),"Memory Address:", id(Age)))
print(f"Height:", Height, ("Type:", type(Height),"Memory Address:", id(Height)))
print(f"Fav_num:", Fav_num, ("Type:", type(Fav_num),"Memory Address:", id(Fav_num)))

from datetime import datetime
current_year=datetime.now().year
birth_year=current_year - Age

print("\nYour birth year is:", birth_year,(f"based on your age of", Age))
print("\nThank you for using the Personal Data Collector. Goodbye!")
# Out:
# Welcome to the interactive personal data collector!
# please enter your name:  Rudhiyansh
# please enter your age:  20
# plaese enter your height in meters:  6.67
# please enter your favourite number:  851184
# Thank you!, Here is the imformation we collected:
#
# Name: Rudhiyansh ('Type:', <class 'str'>, 'Memory Address:', 1746648417648)
# Age: 20 ('Type:', <class 'int'>, 'Memory Address:', 140707016779272)
# Height: 6.67 ('Type:', <class 'float'>, 'Memory Address:', 1746646530320)
# Fav_num: 851184 ('Type:', <class 'int'>, 'Memory Address:', 1746623448272)
#
# Your birth year is: 2006 ('based on your age of', 20)
#
# Thank you for using the Personal Data Collector. Goodbye!
